# %% [markdown]
# <a href="https://colab.research.google.com/github/Niteshrai1328/project/blob/main/matplot_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]
y=[10,20,30,40,50,60]

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title("simple line graph")
plt.xlabel("X Axis")
plt.xlabel("Y Axis")
plt.show()

# %%
plt.plot(x,y,color="blue",linestyle="--",marker="*")
plt.show()

# %% [markdown]
# cyan * line witdth 3to5

# %%
x=[1,2,3,4,5,6]
y=[1,5,36,5,4,8]

#plt.plot(x,y,color="cyan",linestyle="--",linewidth="3",markar="^")
#plt.show()

# %%
plt.plot(x,y,color="cyan",linestyle="--",linewidth="3",marker="^")
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[10,20,30,40,50,60]
plt.plot(x,y,color="cyan",linestyle="--",linewidth="3",marker="^")
plt.show()
#plt.plot(days,temperature,label="Temperature")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1311/2866487828.py in <cell line: 0>()
#       3 #plt.plot(x,y,color="cyan",linestyle="--",linewidth="3",marker="^")
#       4 plt.show()
# ----> 5 plt.plot(days,temperature,label="Temperature")
#       6 plt.legend()
#       7 plt.show()
#
# NameError: name 'days' is not defined

# %%
age=[54,62,36,54,19,61]
plt.hist(age,bins=3)
plt.title("age distribution")
plt.show()

# %%
import numpy as np
import random

# %%
m1_student_age=np.random.randint(15,45,(100))
ai_student_age=np.random.randint(15,40,(100))
print(m1_student_age)
print(ai_student_age)
# Out:
# [22 19 33 28 31 33 16 25 28 21 30 32 21 26 40 29 25 41 18 30 23 42 32 41
#  32 39 40 24 27 17 43 20 23 42 42 29 35 40 35 31 27 27 30 25 24 31 29 23
#  42 31 24 30 30 23 34 17 33 31 36 37 36 15 31 16 35 38 33 30 27 21 27 39
#  43 21 34 41 31 26 22 33 23 26 22 33 18 17 41 42 25 18 40 37 35 25 42 38
#  26 40 17 37]
# [39 30 39 25 34 17 20 25 25 26 26 19 22 37 34 15 15 15 22 24 20 32 23 33
#  15 35 26 26 28 16 26 28 29 38 33 36 17 35 34 39 34 31 26 30 18 25 25 24
#  26 24 28 26 22 16 23 32 28 28 37 19 15 39 35 26 31 25 25 20 15 22 26 31
#  17 18 36 30 31 16 22 22 30 27 23 37 17 27 39 26 30 15 16 37 38 38 27 29
#  17 15 19 21]

# %%
plt.hist(ai_student_age)
plt.show()

# %%
plt.hist(m1_student_age)
plt.show()

# %%
plt.hist(m1_student_age,histtype="bar",color="blue")
plt.hist(ai_student_age,histtype="bar",color="green")
plt.show()

# %%
plt.barh(m1_student_age,ai_student_age)
#plt.barh(ai_student_age)
plt.show()

# %%
plt.pie(ai_student_age)
plt.show()

# %%
a=[1,2,3,4,5,6]
#axplode=[0,0.3,0.2,0,0.1,0.3]
plt.pie(a)
plt.show()

# %%
a=[1,2,3,4,5,6]
explode=[0,0.3,0.2,0,0.1,0.3]
plt.pie(a,explode=explode)
plt.show()

# %%
plt.scatter(ai_student_age,m1_student_age)
plt.show()

# %%
temp=[0,10,20,30,40,50]
sales=[100,200,300,400,500,600]
plt.scatter(temp,sales,color="red",marker="*",alpha=0.5,linewidths=10,edgecolors="g")
plt.xlabel("temperature")
plt.ylabel("sales")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
